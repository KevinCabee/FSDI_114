# %% [markdown]
# # Doubly Linked Lists

# %%
# From scratrch implementation of DLL

class DoublyLinkedList:
    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None
            self.prev = None

    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, value):
        new node = self.__Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node

    def prepend(self, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node

    def insert(self, index, value):
        
        # The insert operation should allow us to create a new node before the target index (with the incoming value)
        # More details: Insert allows you to prepend, append, and insert anywhere between the head and the tail of the list.
        
        new_node = self.__Node(value)
        if not self.head:
            self.append(value)
        else:
            current = self.head
            count = 0
            found = False
            if index == count:
                self.prepend(value)
            else:
                while current and not found:
                    if count == index:
                        found = True
                    else:
                        current = current.next
                        count += 1
                if found:
                    current.prev.next = new_node
                    new_node.prev = current.prev
                    new_node.next = current
                    current.prev = new_node
                else:
                    self.append(value)
                    
                  
            

    def remove(self, value):
        found = False
        if not self.head:
            raise IndexError: (" Nothing to remove ")
        else:
            current = self.head
            while current:
                if current.data == value:
                    current.prev.next = current.next
                    current.next.prev = current.prev
                    found = True
                else:
                    current = current.next
            if not found:
                raise ValueError(" Value not found ")
            
        

    def index(self, value):
        # returns index of first match to value
        count = 0
        found = False
        if self.head:
            current = self.head
            while current and not found:
                if count == index:
                    found = True
                else:
                    current = current.next
                    count += 1
        if found:
            return current.data
        else:
            raise IndexError("Index out of bounds")

    def __getitem__(self, index):
        count = 0
        found = False
        if self.head:
            current = self.head
            while current and not found:
                if count == index:
                    found = True
                else:
                    current = current.next
                    count += 1
        if found:
            return current.data
        else:
            raise IndexError("Index out of bounds")

    def __setitem__(self, index, value):
        count = 0
        found = False
        if self.head:
            current = self.head
            while current and not found:
                if count == index:
                    found = True
                else:
                    current = current.next
                    count += 1
        if found:
            current.data = value

    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % current.data
            while current:
                current = current.next
                if current:
                    out += ", %s" % current.data
        out += "]"
        return out
# Out:
#   Cell In[1], line 15
#     new node = self.__Node(value)
#         ^
# SyntaxError: invalid syntax
